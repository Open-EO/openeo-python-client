# %% [markdown]
# # OpenEO Connection to R Backend

# %%
import openeo
import logging
from openeo.auth.auth_bearer import BearerAuth
logging.basicConfig(level=logging.INFO)

# %%
# Define constants

# Connection
R_DRIVER_URL = "https://r-server.openeo.org"
OUTPUT_FILE = "/tmp/openeo_r_output.png"
OUTFORMAT = "png"

# Auth
USER = "test"
PASSWORD = "test"

# Data
PRODUCT_ID = "sentinel2_subset"

DATE_START = "2017-07-21"
DATE_END = "2017-07-28"

IMAGE_WEST = 7.5
IMAGE_EAST = 8.5
IMAGE_NORTH = 52.0
IMAGE_SOUTH = 51.0
IMAGE_SRS = "EPSG:4326"

# Processes
NDVI_RED = "B4"
NDVI_NIR = "B8"

STRECH_COLORS_MIN = -1
STRECH_COLORS_MAX = 1

# %%
# Connect with R backend
connection = openeo.connect(R_DRIVER_URL, auth_type=BearerAuth, auth_options={"username": USER, "password": PASSWORD})
connection

# %%
# Get available processes from the back end.
processes = connection.list_processes()
processes
# Out:
# [{'description': 'filters a data set with a temporal dimension based on a stated start and end date',
#   'min_parameters': 1,
#   'name': 'filter_daterange',
#   'parameters': {'extent': {'description': 'an Array containing start and stop date/timestamp for the query interval',
#     'required': False,
#     'schema': {'type': 'temporal-extent'}},
#    'imagery': {'description': 'the temporal dataset/collection',
#     'required': True,
#     'schema': {'format': 'eodata', 'type': 'object'}}},
#   'returns': {'description': 'Processed EO data.',
#    'schema': {'format': 'eodata', 'type': 'object'}},
#   'summary': 'Filter by a date range'},
#  {'description': 'calculates the minimum value per pixel of a single valued band collection',
#   'min_parameters': 1,
#   'name': 'min_time',
#   'parameters': {'imagery': {'description': 'the temporal dataset/collection',
#     'required': True,
#     'schema': {'format': 'eodata', 'type': 'object'}}},
#   'returns': {'description': 'Processed EO data.',
#    'schema': {'format': 'eodata', 'type': 'object'}},
#   'summary': 'Minimum value of collections per pixel'},
#  {'description': 'calculates the maximum value per pixel of a single valued band collection',
#   'min_parameters': 1,
#   'name': 'max_time',
#   'parameters': {'imagery': {'description': 'the temporal dataset/collection',
#     'required': True,
#     'schema': {'format': 'eodata', 'type': 'object'}}},
#   'returns': {'description': 'Processed EO data.',
#    'schema': {'format': 'eodata', 'type': 'object'}},
#   'summary': 'Minimum value of collections per pixel'},
#  {'description': 'Calculates the ndvi per pixel and scene in a given collection',
#   'min_parameters': 1,
#   'name': 'NDVI',
#   'parameters': {'imagery': {'description': 'the spatio-temporal dataset/collection',
#     'required': True,
#     'schema': {'format': 'eodata', 'type': 'object'}},
#    'nir': {'description': 'The band id of the Near Infrared (NIR) band',
#     'required': True,
#     'schema': {'type': 'string'}},
#    'red': {'description': 'The band id of the visible red band',
#     'required': True,
#     'schema': {'type': 'string'}}},
#   'returns': {'description': 'Processed EO data.',
#    'schema': {'format': 'eodata', 'type': 'object'}},
#   'summary': 'NDVI calculation per pixel'},
#  {'description': 'filters by single and multiple band ids',
#   'min_parameters': 1,
#   'name': 'filter_bands',
#   'parameters': {'bands': {'description': 'one or more band ids',
#     'required': True,
#     'schema': {'type': ['string', 'array']}},
#    'imagery': {'description': 'the temporal dataset/collection',
#     'required': True,
#     'schema': {'format': 'eodata', 'type': 'object'}}},
#   'returns': {'description': 'Processed EO data.',
#    'schema': {'format': 'eodata', 'type': 'object'}},
#   'summary': 'Filter by band(s)'},
#  {'description': 'Calculates the zonal statistics from a given file containing polygons and returns a spatial polygon dataframe. It should not be nested in other calls which require imagery.',
#   'min_parameters': 1,
#   'name': 'zonal_statistics',
#   'parameters': {'func': {'description': "An aggregation function like 'mean', 'median' or 'sum'",
#     'required': True,
#     'schema': {'type': 'string'}},
#    'imagery': {'description': 'The imagery data set on which the zonal statistics shall be performed',
#     'required': True,
#     'schema': {'format': 'eodata', 'type': 'object'}},
#    'regions': {'description': 'The relative link in the user workspace, where to find the geometries file',
#     'required': True,
#     'schema': {'format': 'url', 'type': 'string'}}},
#   'returns': {'description': 'Processed Vector data derived from extraction of EOData.',
#    'schema': {'format': 'vector', 'type': 'object'}},
#   'summary': 'Zonal statistics for polygons on EO data'},
#  {'description': 'Subsets an imagery by a specific extent',
#   'min_parameters': 1,
#   'name': 'filter_bbox',
#   'parameters': {'extent': {'description': 'Spatial extent as object [west,south,east,north,crs,...], may include a vertical axis (height or depth)',
#     'required': True,
#     'schema': {'type': 'spatial_extent'}},
#    'imagery': {'description': 'the spatio-temporal dataset/collection',
#     'required': True,
#     'schema': {'format': 'eodata', 'type': 'object'}}},
#   'returns': {'description': 'Processed EO data.',
#    'schema': {'format': 'eodata', 'type': 'object'}},
#   'summary': 'Spatial filter with Bounding Box'},
#  {'description': 'Applies UDF of type aggregate_time on an object of class Collection',
#   'min_parameters': 1,
#   'name': 'aggregate_time',
#   'parameters': {'imagery': {'description': 'the spatio-temporal dataset/collection',
#     'required': True,
#     'schema': {'format': 'eodata', 'type': 'object'}},
#    'script': {'description': "the URL or path relative to the current working directory to the user's R script containing the UDF definition",
#     'required': True,
#     'schema': {'format': 'url', 'type': 'string'}},
#    'udf_runtime': {'description': 'the identifier which UDF strategy is used.',
#     'required': False,
#     'schema': {'type': 'string'}}},
#   'returns': {'description': 'Processed EO data.',
#    'schema': {'format': 'eodata', 'type': 'object'}},
#   'summary': 'UDF: Applies an aggregation function over time.'},
#  {'description': 'Applies UDF of type apply_pixel on an object of class Collection',
#   'min_parameters': 1,
#   'name': 'apply_pixel',
#   'parameters': {'imagery': {'description': 'the spatio-temporal dataset/collection',
#     'required': True,
#     'schema': {'format': 'eodata', 'type': 'object'}},
#    'script': {'description': "the URL or path relative to the current working directory to the user's R script containing the UDF definition",
#     'required': True,
#     'schema': {'format': 'url', 'type': 'string'}},
#    'udf_runtime': {'description': 'the identifier which UDF strategy is used.',
#     'required': False,
#     'schema': {'type': 'string'}}},
#   'returns': {'description': 'Processed EO data.',
#    'schema': {'format': 'eodata', 'type': 'object'}},
#   'summary': 'UDF: applies a function pixel wise'},
#  {'description': 'Loads the EO data into a process',
#   'min_parameters': 1,
#   'name': 'get_collection',
#   'parameters': {'name': {'description': 'the temporal dataset/collection',
#     'required': True,
#     'schema': {'type': 'string'}}},
#   'returns': {'description': 'Processed EO data.',
#    'schema': {'format': 'eodata', 'type': 'object'}},
#   'summary': 'Select a collection'}]

# %%
# Retrieve the list of available collections
collections = connection.list_collections()

list(collections)[:2]
# Out:
# [{'description': 'Sentinel 2 raster time series for a small spatial subset',
#   'extent': {'spatial': [22.8994, -19.0099, 22.9282, -18.9825],
#    'temporal': ['2016-12-12T08:23:32Z', '2017-08-29T08:16:01Z']},
#   'license': 'propietary',
#   'links': [{'href': 'https://scihub.copernicus.eu/twiki/pub/SciHubWebPortal/TermsConditions/TC_Sentinel_Data_31072014.pdf',
#     'rel': 'license'},
#    {'href': 'https://r-server.openeo.org/collections/sentinel2_subset',
#     'rel': 'self'}],
#   'name': 'sentinel2_subset',
#   'title': 'Sentinel-2A MSI L1C subset'},
#  {'description': 'Calculated NDVI raster time series for a small spatial subset derived from Landsat-7',
#   'extent': {'spatial': [35.7114, 7.1295, 35.8024, 7.2204],
#    'temporal': ['2003-08-06T00:00:00Z', '2014-12-26T00:00:00Z']},
#   'license': 'propietary',
#   'links': [{'href': 'https://landsat.usgs.gov/sites/default/files/documents/Landsat_Data_Policy.pdf',
#     'rel': 'license'},
#    {'href': 'https://r-server.openeo.org/collections/landsat7_ndvi',
#     'rel': 'self'}],
#   'name': 'landsat7_ndvi',
#   'title': 'NDVI derived from Landsat 7'}]

# %%
# Get detailed information about a collection
process = connection.describe_collection(PRODUCT_ID)
process
# Out:
# {'description': 'Sentinel 2 raster time series for a small spatial subset',
#  'eo:bands': {'B1': {'center_wavelength': 4.439,
#    'common_name': 'coastal',
#    'offset': 0,
#    'resolution': 60,
#    'scale': 1},
#   'B10': {'center_wavelength': 1.3735,
#    'offset': 0,
#    'resolution': 60,
#    'scale': 1},
#   'B11': {'center_wavelength': 1.6137,
#    'common_name': 'swir16',
#    'offset': 0,
#    'resolution': 20,
#    'scale': 1},
#   'B12': {'center_wavelength': 2.2024,
#    'common_name': 'swir22',
#    'offset': 0,
#    'resolution': 20,
#    'scale': 1},
#   'B2': {'center_wavelength': 4.966,
#    'common_name': 'blue',
#    'offset': 0,
#    'resolution': 10,
#    'scale': 1},
#   'B3': {'center_wavelength': 5.6,
#    'common_name': 'green',
#    'offset': 0,
#    'resolution': 10,
#    'scale': 1},
#   'B4': {'center_wavelength': 6.645,
#    'common_name': 'red',
#    'offset': 0,
#    'resolution': 10,
#    'scale': 1},
#   'B5': {'center_wavelength': 7.039,
#    'offset': 0,
#    'resolution': 20,
#    'scale': 1},
#   'B6': {'center_wavelength': 7.402,
#    'offset': 0,
#    'resolution': 20,
#    'scale': 1},
#   'B7': {'center_wavelength': 7.825,
#    'offset': 0,
#    'resolution': 20,
#    'scale': 1},
#   'B8': {'center_wavelength': 8.351,
#    'common_name': 'nir',
#    'offset': 0,
#    'resolution': 10,
#    'scale': 1},
#   'B8A': {'center_wavelength': 8.648,
#    'offset': 0,
#    'resolution': 20,
#    'scale': 1},
#   'B9': {'center_wavelength': 9.45,
#    'offset': 0,
#    'resolution': 60,
#    'scale': 1}},
#  'eo:constellation': 'sentinel-2',
#  'eo:epsg': 32734,
#  'eo:platform': 'sentinel-2a',
#  'extent': {'spatial': [22.8994, -19.0099, 22.9282, -18.9825],
#   'temporal': ['2016-12-12T08:23:32Z', '2017-08-29T08:16:01Z']},
#  'keywords': ['sentinel-2'],
#  'license': 'propietary',
#  'links': [{'href': 'https://scihub.copernicus.eu/twiki/pub/SciHubWebPortal/TermsConditions/TC_Sentinel_Data_31072014.pdf',
#    'rel': 'license'},
#   {'href': 'https://r-server.openeo.org/collections/sentinel2_subset',
#    'rel': 'self'}],
#  'name': 'sentinel2_subset',
#  'provider': [{'name': 'European Space Agency (ESA)',
#    'url': 'https://sentinel.esa.int/web/sentinel/user-guides/sentinel-2-msi'}],
#  'title': 'Sentinel-2A MSI L1C subset',
#  'version': '0.0.1'}

# %%
# Select collection product
datacube = connection.imagecollection(PRODUCT_ID)

print(datacube.to_json())
# Out:
# {'name': 'sentinel2_subset', 'process_id': 'get_collection'}

# %%
# Specifying the date range and the bounding box
datacube = datacube.filter_bbox(west=IMAGE_WEST, east=IMAGE_EAST, north=IMAGE_NORTH,
                                             south=IMAGE_SOUTH, crs=IMAGE_SRS)
datacube = datacube.filter_daterange(extent=[DATE_START, DATE_END])

print(datacube.to_json())
# Out:
# {'extent': ['2017-07-21', '2017-07-28'],
#  'imagery': {'extent': {'crs': 'EPSG:4326',
#    'east': 8.5,
#    'north': 52.0,
#    'south': 51.0,
#    'west': 7.5},
#   'imagery': {'name': 'sentinel2_subset', 'process_id': 'get_collection'},
#   'process_id': 'filter_bbox'},
#  'process_id': 'filter_daterange'}

# %%
# Applying some operations on the data
datacube = datacube.ndvi(red=NDVI_RED, nir=NDVI_NIR)
datacube = datacube.min_time()

print(datacube.to_json())
# Out:
# {'imagery': {'imagery': {'extent': ['2017-07-21', '2017-07-28'],
#    'imagery': {'extent': {'crs': 'EPSG:4326',
#      'east': 8.5,
#      'north': 52.0,
#      'south': 51.0,
#      'west': 7.5},
#     'imagery': {'name': 'sentinel2_subset', 'process_id': 'get_collection'},
#     'process_id': 'filter_bbox'},
#    'process_id': 'filter_daterange'},
#   'nir': 'B8',
#   'process_id': 'NDVI',
#   'red': 'B4'},
#  'process_id': 'min_time'}

# %%
# Sending the job to the backend
job = datacube.create_job()
job.start_job()
job

# %%
# Describe Job
job.describe_job()
# Out:
# {'budget': None,
#  'costs': 0,
#  'description': None,
#  'job_id': '9P5eXrzcOBXCfdK',
#  'output': {'format': {}, 'parameters': {}},
#  'plan': None,
#  'process_graph': {'imagery': {'imagery': {'extent': ['2017-07-21',
#      '2017-07-28'],
#     'imagery': {'extent': {'crs': 'EPSG:4326',
#       'east': 8.5,
#       'north': 52,
#       'south': 51,
#       'west': 7.5},
#      'imagery': {'name': 'sentinel2_subset', 'process_id': 'get_collection'},
#      'process_id': 'filter_bbox'},
#     'process_id': 'filter_daterange'},
#    'nir': 'B8',
#    'process_id': 'NDVI',
#    'red': 'B4'},
#   'process_id': 'min_time'},
#  'status': 'error',
#  'submitted': '2019-05-21T13:31:50Z',
#  'title': None,
#  'updated': '2019-05-21T13:31:51Z'}

# %%
# Download job result
job.download_results(OUTPUT_FILE)

job
# Out:
# ---------------------------------------------------------------------------
# ConnectionAbortedError                    Traceback (most recent call last)
# <ipython-input-13-a5d99fafe606> in <module>
#       1 # Download job result
# ----> 2 job.download_results(OUTPUT_FILE)
#       3
#       4 job
#
# /data/REPO/openeo-python-client/openeo/rest/job.py in download_results(self, target)
#      98                     handle.write(block)
#      99         else:
# --> 100             raise ConnectionAbortedError(r.text)
#     101         return r.status_code
#     102
#
# ConnectionAbortedError: {"code":3006,"message":"Job has not finished computing the results yet. Please try again later.","links":[]}

# %%
# Showing the result
from IPython.display import Image
result = Image(filename=OUTPUT_FILE)

result
